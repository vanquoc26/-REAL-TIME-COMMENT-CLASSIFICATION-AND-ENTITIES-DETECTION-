# %%
from google.colab import drive
import os

drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.multioutput import MultiOutputClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
data_path = '/content/drive/MyDrive/UIT SUBJECT/Big Data/Data/output.csv'
data = pd.read_csv(data_path)

data
# Out:
#       Index                                            Comment  \
# 0         0                                  garnacho bảnh quá
# 1         1                               bình an đăng lại kìa
# 2         2                                 gọi garnacho là gì
# 3         3  chỉnh sửa đẹp , ngầu âm thanh chất lượng nhưng...
# 4         4      hâm mộ manchester city những vẫn thích united
# ...     ...                                                ...
# 5109   5573                 romelu lukaku khiến tôi bán xe rồi
# 5110   5574         bỉ là đội yếu chứ không mạnh như mầy tưởng
# 5111   5575  đồng tiền lái đôi chân đá trượt bóng luôn khi ...
# 5112   5576  vứt lịch thi đấu mới quan trọng còn nhận định ...
# 5113   5577  15 đội xuất sắc thôi còn thằng anh chỉ là kẻ l...
#
#                                   Object  Label tu_viet_tat  \
# 0                               garnacho    1.0         NaN
# 1                                    NaN    0.0         NaN
# 2                               garnacho    0.0         NaN
# 3                                    NaN    0.0           k
# 4     manchester city, manchester united    1.0      mc, mu
# ...                                  ...    ...         ...
# 5109                       romelu lukaku    2.0     lukacặk
# 5110                                  bỉ    2.0         NaN
# 5111                                 NaN    2.0         NaN
# 5112                                 NaN    2.0         NaN
# 5113                                 anh    2.0         NaN
#
#                                  meaning  xoa_khong
# 0                                    NaN        NaN
# 1                                    NaN        NaN
# 2                                    NaN        NaN
# 3                                  không        NaN
# 4     manchester city, manchester united        NaN
# ...                                  ...        ...
# 5109                       romelu lukaku        NaN
# 5110                                 NaN        NaN
# 5111                                 NaN        NaN
# 5112                                 NaN        NaN
# 5113                                 NaN        NaN
#
# [5114 rows x 7 columns]

# %%
data = data[['Comment', 'Object', 'Label']]

# %%
predict_data = data[~data['Label'].isin([0, 1, 2])].reset_index(drop=True)
data = data[data['Label'].isin([0, 1, 2])].reset_index(drop=True)

# %%
data = data[['Comment', 'Object']]
predict_data = predict_data[['Comment', 'Object']]

data
# Out:
#                                                 Comment  \
# 0                                     garnacho bảnh quá
# 1                                  bình an đăng lại kìa
# 2                                    gọi garnacho là gì
# 3     chỉnh sửa đẹp , ngầu âm thanh chất lượng nhưng...
# 4         hâm mộ manchester city những vẫn thích united
# ...                                                 ...
# 2322                 romelu lukaku khiến tôi bán xe rồi
# 2323         bỉ là đội yếu chứ không mạnh như mầy tưởng
# 2324  đồng tiền lái đôi chân đá trượt bóng luôn khi ...
# 2325  vứt lịch thi đấu mới quan trọng còn nhận định ...
# 2326  15 đội xuất sắc thôi còn thằng anh chỉ là kẻ l...
#
#                                   Object
# 0                               garnacho
# 1                                    NaN
# 2                               garnacho
# 3                                    NaN
# 4     manchester city, manchester united
# ...                                  ...
# 2322                       romelu lukaku
# 2323                                  bỉ
# 2324                                 NaN
# 2325                                 NaN
# 2326                                 anh
#
# [2327 rows x 2 columns]

# %% [markdown]
# # Huấn luyện mô hình

# %%
data.isnull().sum()
# Out:
# Comment      0
# Object     957
# dtype: int64

# %%
# Chuẩn bị dữ liệu
data['Object'] = data['Object'].fillna('')
data['Object'] = data['Object'].apply(lambda x: x.split(',') if x else [])

data
# Out:
#                                                 Comment  \
# 0                                     garnacho bảnh quá
# 1                                  bình an đăng lại kìa
# 2                                    gọi garnacho là gì
# 3     chỉnh sửa đẹp , ngầu âm thanh chất lượng nhưng...
# 4         hâm mộ manchester city những vẫn thích united
# ...                                                 ...
# 2322                 romelu lukaku khiến tôi bán xe rồi
# 2323         bỉ là đội yếu chứ không mạnh như mầy tưởng
# 2324  đồng tiền lái đôi chân đá trượt bóng luôn khi ...
# 2325  vứt lịch thi đấu mới quan trọng còn nhận định ...
# 2326  15 đội xuất sắc thôi còn thằng anh chỉ là kẻ l...
#
#                                      Object
# 0                                [garnacho]
# 1                                        []
# 2                                [garnacho]
# 3                                        []
# 4     [manchester city,  manchester united]
# ...                                     ...
# 2322                        [romelu lukaku]
# 2323                                   [bỉ]
# 2324                                     []
# 2325                                     []
# 2326                                  [anh]
#
# [2327 rows x 2 columns]

# %%
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(data['Comment'])

# Chuẩn bị nhãn cho các chủ thể
all_objects = list(set([obj.strip() for sublist in data['Object'] for obj in sublist]))
Y = np.zeros((data.shape[0], len(all_objects)))

for i, objects in enumerate(data['Object']):
    for obj in objects:
        if obj.strip() in all_objects:
            Y[i, all_objects.index(obj.strip())] = 1

# %%
# Chia dữ liệu thành tập huấn luyện và kiểm tra
X_train, X_test, Y_train, Y_test, train_index, test_index = train_test_split(X, Y, data.index, test_size=0.2, random_state=42)

# Huấn luyện mô hình Naive Bayes
nb = MultinomialNB()
multi_target_nb = MultiOutputClassifier(nb, n_jobs=-1)
multi_target_nb.fit(X_train, Y_train)
# Out:
# MultiOutputClassifier(estimator=MultinomialNB(), n_jobs=-1)

# %% [markdown]
# Predict- Tập test

# %%
# Dự đoán trên dữ liệu kiểm tra
Y_pred = multi_target_nb.predict(X_test)

# %%
def convert_to_entities(y):
    return [', '.join([all_objects[i] for i in range(len(all_objects)) if y[j, i] == 1]) for j in range(y.shape[0])]

# Tạo DataFrame với các comment và dự đoán
test_comments = data['Comment'].iloc[test_index]
test_actual_objects = convert_to_entities(Y_test)
test_predicted_objects = convert_to_entities(Y_pred)

test_results = pd.DataFrame({
    'Comment': test_comments,
    'Actual_Objects': test_actual_objects,
    'Predicted_Objects': test_predicted_objects
})

# %%
# Hiển thị kết quả
test_results
# Out:
#                                                 Comment     Actual_Objects  \
# 1736  tối qua bồ đào nha nhiều ông đá như chơi không...         bồ đào nha
# 755                    cristiano ronaldo là màu mè nhất  cristiano ronaldo
# 1669          quang hải đi qua nước ngoài nhặt bóng rồi          quang hải
# 1322                                               yahh
# 1870                      quá là xuất sắc việt namm ơii           việt nam
# ...                                                 ...                ...
# 1360                                       máy chạy top
# 1989    và con tim đã vui trở lại tuyệt vời việt nam ơi           việt nam
# 786                                          di dimaria            dimaria
# 2280                                        bỉ 2 1 pháp           pháp, bỉ
# 889                                                kaka               kaka
#
#       Predicted_Objects
# 1736
# 755   cristiano ronaldo
# 1669
# 1322
# 1870
# ...                 ...
# 1360
# 1989           việt nam
# 786             dimaria
# 2280
# 889
#
# [466 rows x 3 columns]

# %% [markdown]
# Thông số kiểm tra

# %%
accuracy = accuracy_score(Y_test, Y_pred)
precision = precision_score(Y_test, Y_pred, average='micro')
recall = recall_score(Y_test, Y_pred, average='micro')
f1 = f1_score(Y_test, Y_pred, average='micro')

print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1 Score: {f1}')
# Out:
# Accuracy: 0.648068669527897
# Precision: 0.4570446735395189
# Recall: 0.4117647058823529
# F1 Score: 0.4332247557003257
